# %%
# Scraping and cleaning with pandas

# %%
import pandas as pd

# %%
spotify_csv="spotify_top_200.csv"

# %%
spotify_df=pd.read_csv(spotify_csv)

# %%
spotify_df
# Out:
#      Position                                         Track Name  \
# 0           1                                    Blinding Lights
# 1           2                                            The Box
# 2           3                                       Dance Monkey
# 3           4                                    Don't Start Now
# 4           5                           Intentions (feat. Quavo)
# 5           6                                         Ignorantes
# 6           7                                         La Difícil
# 7           8                                               Tusa
# 8           9                                   Si Veo a Tu Mamá
# 9          10                                             Say So
# 10         11                                            Falling
# 11         12                                            ROXANNE
# 12         13                                        Stupid Love
# ...

# %%
type(spotify_df)
# Out:
# pandas.core.frame.DataFrame

# %%
Spotify_df=spotify_df.drop(columns=['URL'])

# %%
Spotify_df
# Out:
#      Position                                         Track Name  \
# 0           1                                    Blinding Lights
# 1           2                                            The Box
# 2           3                                       Dance Monkey
# 3           4                                    Don't Start Now
# 4           5                           Intentions (feat. Quavo)
# 5           6                                         Ignorantes
# 6           7                                         La Difícil
# 7           8                                               Tusa
# 8           9                                   Si Veo a Tu Mamá
# 9          10                                             Say So
# 10         11                                            Falling
# 11         12                                            ROXANNE
# 12         13                                        Stupid Love
# ...

# %%
# Creating html table of spotify_df

# %%
Spotify_html_table=Spotify_df.to_html()

# %%
Spotify_html_table
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Position</th>\n      <th>Track Name</th>\n      <th>Artist</th>\n      <th>Streams</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>1</td>\n      <td>Blinding Lights</td>\n      <td>The Weeknd</td>\n      <td>43316941</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>2</td>\n      <td>The Box</td>\n      <td>Roddy Ricch</td>\n      <td>39070218</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>3</td>\n      <td>Dance Monkey</td>\n      <td>Tones and I</td>\n      <td>38072447</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>4</td>\n      <td>Don\'t Start Now</td>\n      <td>Dua Lipa</td>\n      <td>33460126</td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>5</td>\n      <td>Intentions (feat. Quavo)</td>\n      <td>Justin Bieber</td>\n      <td>29542408</td>\n    </tr>\n    <tr>\n      <th>5</th>\n      <td>6</td>\n      <t
# ...

# %%
#Stripping unwanted newlines to clean up the table

# %%
Spotify_html_table.replace('\n', '')
# Out:
# '<table border="1" class="dataframe">  <thead>    <tr style="text-align: right;">      <th></th>      <th>Position</th>      <th>Track Name</th>      <th>Artist</th>      <th>Streams</th>    </tr>  </thead>  <tbody>    <tr>      <th>0</th>      <td>1</td>      <td>Blinding Lights</td>      <td>The Weeknd</td>      <td>43316941</td>    </tr>    <tr>      <th>1</th>      <td>2</td>      <td>The Box</td>      <td>Roddy Ricch</td>      <td>39070218</td>    </tr>    <tr>      <th>2</th>      <td>3</td>      <td>Dance Monkey</td>      <td>Tones and I</td>      <td>38072447</td>    </tr>    <tr>      <th>3</th>      <td>4</td>      <td>Don\'t Start Now</td>      <td>Dua Lipa</td>      <td>33460126</td>    </tr>    <tr>      <th>4</th>      <td>5</td>      <td>Intentions (feat. Quavo)</td>      <td>Justin Bieber</td>      <td>29542408</td>    </tr>    <tr>      <th>5</th>      <td>6</td>      <td>Ignorantes</td>      <td>Bad Bunny</td>      <td>29245976</td>    </tr>    <tr>      <th>6</th> 
# ...

# %%
#Saving the table to a file

# %%
Spotify_df.to_html('table.html')
